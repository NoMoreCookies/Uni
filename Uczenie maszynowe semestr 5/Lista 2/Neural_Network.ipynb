# %% [markdown]
# Neuron - Thing that holds a number

# %% [markdown]
# ![Neuron - Thing that holds a number](assets/Neuron.png)

# %% [markdown]
# Especially neuron can hold numbers between 0 and 1

# %% [markdown]
# Network starts with bunch of neurons, each one corresponding to every pixel in given letter

# %% [markdown]
# ![Neuron - Thing that holds a number](assets/Number_grid.png)
